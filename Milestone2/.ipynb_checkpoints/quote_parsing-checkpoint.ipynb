# %%
import json
import bz2
import sys
import os
import pandas as pd
import time
import matplotlib.pyplot as plt
import numpy as np

# %%
#specification of dataset reading parameters and folders path 
CHUNKSIZE=200
QUOTEBANK_POLITICIANS_USA=  'quotebank_politicians_USA.json.bz2' # US politician quotes
WIKI_DATA_FILTERED_LABELED = 'filtered_politician_labeled_v2.json.bz2' # filtered wikidata with interpretations
POLITICIANS_MENTIONS_USA= 'politicians_mentions_USA.json.bz2'#
qids_df=pd.read_json(WIKI_DATA_FILTERED_LABELED, lines=True)

# %%
politician_df=pd.read_json(WIKI_DATA_FILTERED_LABELED, lines=True)
politician_df.head()
# Out:
#      qid              name gender nationality  \
# 0   Q207    George W. Bush   male         Q30
# 1   Q946       Donald Tusk   male         Q36
# 2  Q1058     Narendra Modi   male        Q668
# 3  Q1253       Ban Ki-moon   male        Q884
# 4  Q3996  V. P. Kalairajan   male        Q668
#
#                                              aliases  \
# 0  [George Walker Bush, Bush Jr., Dubya, GWB, Bus...
# 1                           [Donald Franciszek Tusk]
# 2  [Modi, Narendra Bhai, Narendra Damodardas Modi...
# 3                          [Ban Kimoon, Ban Ki Moon]
# 4                                                 []
#
#                                       parties  \
# 0                          [Republican Party]
# 1   [Civic Platform, European People's Party]
# 2                    [Bharatiya Janata Party]
# 3                    [independent politician]
# 4  [All India Anna Dravida Munnetra Kazhagam]
#
#                                       positions held religion us_congress_id  \
# 0  [Q5589725, [[+1995-01-17T00:00:00Z]], Q11696, ...  Q329646
# 1  [Q3259469, [[+2007-11-16T00:00:00Z]], Q735587,...    Q9592
# 2  [Q22337580, [[+2001-10-07T00:00:00Z]], Q425092...    Q9089
# 3  [Q81066, [[+2007-01-01T00:00:00Z]], [Foreign m...    Q9581
# 4                                  [Q24558764, [[]]]
#
#                                   candidacy_election
# 0  [2000 United States presidential election, 200...
# 1                [2005 Polish presidential election]
# 2  [2014 Indian general election in Vadodara Lok ...
# 3                                                 []
# 4                                                 []

# %%
politician_us_df = qids_df[qids_df['nationality']=='Q30']
politician_us_df.head()
# Out:
#        qid            name gender nationality  \
# 0     Q207  George W. Bush   male         Q30
# 5    Q4496     Mitt Romney   male         Q30
# 7   Q11124  Stephen Breyer   male         Q30
# 9   Q11674  David Paterson   male         Q30
# 23  Q22201      Jim DeMint   male         Q30
#
#                                               aliases             parties  \
# 0   [George Walker Bush, Bush Jr., Dubya, GWB, Bus...  [Republican Party]
# 5               [Willard Mitt Romney, Pierre Delecto]  [Republican Party]
# 7                             [Stephen Gerald Breyer]  [Democratic Party]
# 9                          [David Alexander Paterson]  [Democratic Party]
# 23   [James Warren "Jim" DeMint, James Warren DeMint]  [Republican Party]
#
#                                        positions held religion us_congress_id  \
# 0   [Q5589725, [[+1995-01-17T00:00:00Z]], Q11696, ...  Q329646
# 5   [Q887117, [[+2003-01-02T00:00:00Z]], [bishop, ...   Q42504        R000615
# 7   [Q11144, [[+1994-08-03T00:00:00Z]], Q23930295,...    Q9268
# 9   [Q2347975, [[+2008-03-17T00:00:00Z]], Q6544428...
# 23  [[United States representative, []], [United S...  Q178169        D000595
#
#                                    candidacy_election
# 0   [2000 United States presidential election, 200...
# 5   [2012 Republican Party presidential primaries,...
# 7                                                  []
# 9                                                  []
# 23                                                 []

# %%
names_us=politician_us_df[['qid','name','aliases']]
names_us.head()
# Out:
#        qid            name                                            aliases
# 0     Q207  George W. Bush  [George Walker Bush, Bush Jr., Dubya, GWB, Bus...
# 5    Q4496     Mitt Romney              [Willard Mitt Romney, Pierre Delecto]
# 7   Q11124  Stephen Breyer                            [Stephen Gerald Breyer]
# 9   Q11674  David Paterson                         [David Alexander Paterson]
# 23  Q22201      Jim DeMint   [James Warren "Jim" DeMint, James Warren DeMint]

# %%
i=3
tri='George Walker Bush is ok'
for index,politic in names_us.iterrows():
    if (i<6) :
        print(index)
        print(politic['aliases'])
        for name in politic['aliases']:
            if(name in tri):
                print(name)
                
            
        
        i+=1
# Out:
# 0
# ['George Walker Bush', 'Bush Jr.', 'Dubya', 'GWB', 'Bush 43', 'President George W. Bush', 'George Bush', 'President Bush', 'Bush', 'Bush, George W.']
# George Walker Bush
# Bush
# 5
# ['Willard Mitt Romney', 'Pierre Delecto']
# 7
# ['Stephen Gerald Breyer']

# %%
#extraction of political name's mention from the quotes
try:
    os.remove(POLITICIANS_MENTIONS_USA)
except:
    pass
total_time,total_mentions,chunk_number,nb_quote=0,0,0,0
mentions=[]
with bz2.open(POLITICIANS_MENTIONS_USA, 'wb') as bzout_mention_usa:
    with pd.read_json(QUOTEBANK_POLITICIANS_USA, lines=True, chunksize=CHUNKSIZE, compression='bz2' ) as df_reader:
        for chunk in df_reader:
            t1=time.time()
            for quote in chunk.quotation :
                for index,politic in names_us.iterrows():
                    if(politic['name'] in quote):
                        try:
                            mentions.append(dict(zip(['qid_quote', 'qid_speaker','qid_mentioned'], [chunk['quoteID'],chunk['qids'],politic['qid']])))# dump quoteID, and qid of speaker and cited
                            total_mentions+=1
                        except KeyError as e:
                            print(e,names['id'])
                    else :
                        for alias in politic['aliases']:
                            if(alias in quote):
                                try:
                                    mentions.append(dict(zip(['qid_quote', 'qid_speaker','qid_mentioned'], [chunk['quoteID'],chunk['qids'],politic['qid']])))#  dump quoteID, and qid of speaker and cited
                                    total_mentions+=1
                                except KeyError as e:
                                    print(e,names['id'])
                                break;
            t2=time.time()
            dt=t2-t1
            total_time+=dt
            chunk_number += 1
            print(chunk_number)
            print("from {} US political quotations there is {} mentions [time: {:.2f}]".format(chunk_number*CHUNKSIZE, total_mentions, total_time))
            #bzout_mention_usa.write(('\n'.join(map(json.dumps, mentions))+'\n').encode('utf-8'))
            #json.dump(bzout_mention_usa,orient='records',lines=True)
            pd.DataFrame(mentions).to_json(path_or_buf=bzout_mention_usa,orient='records',lines=True)
            mentions = []
# Out:
# 1
# from 200 US political quotations there is 11 mentions [time: 235.91]
# 2
# from 400 US political quotations there is 39 mentions [time: 472.24]
# 3
# from 600 US political quotations there is 61 mentions [time: 707.55]
# 4
# from 800 US political quotations there is 88 mentions [time: 943.98]
# 5
# from 1000 US political quotations there is 99 mentions [time: 1188.08]
# 6
# from 1200 US political quotations there is 113 mentions [time: 1423.94]
# 7
# from 1400 US political quotations there is 129 mentions [time: 1661.21]
# 8
# from 1600 US political quotations there is 150 mentions [time: 1895.35]
# 9
# from 1800 US political quotations there is 174 mentions [time: 2133.26]
# 10
# from 2000 US political quotations there is 187 mentions [time: 2371.90]
# 11
# from 2200 US political quotations there is 207 mentions [time: 2621.56]
# 12
# from 2400 US political quotations there is 229 mentions [time: 2884.09]
# 13
# from 2600 US political quotations there is 252 mentions [time: 3124.39]
# 14
# from 2800 US political quotations there is 273 mentions [time: 3360.22]
# 15
# from 3000 US political quotations there is 288 mentions [time: 3596.25]
# 16
# from 3200 US political quotations there is 309 mentions [time: 3831.38]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/r7/jht38nh56px_s6jkntzx89n00000gn/T/ipykernel_40234/425707650.py in <module>
#      11             t1=time.time()
#      12             for quote in chunk.quotation :
# ---> 13                 for index,politic in names_us.iterrows():
#      14                     if(politic['name'] in quote):
#      15                         try:
#
# ~/opt/anaconda3/envs/ada/lib/python3.8/site-packages/pandas/core/frame.py in iterrows(self)
#    1261         klass = self._constructor_sliced
#    1262         for k, v in zip(self.index, self.values):
# -> 1263             s = klass(v, index=columns, name=k)
#    1264             yield k, s
#    1265
#
# ~/opt/anaconda3/envs/ada/lib/python3.8/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     439                 data = sanitize_array(data, index, dtype, copy)
#     440
# --> 441                 manager = get_option("mode.data_manager")
#     442                 if manager == "block":
#     443                     data = SingleBlockManager.from_array(data, index)
#
# ~/opt/anaconda3/envs/ada/lib/python3.8/site-packages/pandas/_config/config.py in __call__(self, *args, **kwds)
#     241
#     242     def __call__(self, *args, **kwds):
# --> 243         return self.__func__(*args, **kwds)
#     244
#     245     @property
#
# KeyboardInterrupt:

# %%
#extraction of political name's mention from the quotes
try:
    os.remove(POLITICIANS_MENTIONS_USA)
except:
    pass
total_time,total_mentions,chunk_number,nb_quote=0,0,0,0
mentions=[]
with bz2.open(POLITICIANS_MENTIONS_USA, 'wb') as bzout_mention_usa:
    with pd.read_json(QUOTEBANK_POLITICIANS_USA, lines=True, chunksize=CHUNKSIZE, compression='bz2' ) as df_reader:
        for chunk in df_reader:
            t1=time.time()
            for idd,quote in enumerate(chunk.quotation) :
                nb_quote+=1
                for index,politic in names_us.iterrows():
                    if(politic['name'] in quote):
                        try:
                            mentions.append(dict(zip(['qid_quote', 'qid_speaker','qid_mentioned'], [chunk['quoteID'][idd],chunk['qids'][idd],politic['qid']])))# dump quoteID, and qid of speaker and cited
                            total_mentions+=1
                        except KeyError as e:
                            print(e,names_us['qid'])
                    else :
                        for alias in politic['aliases']:
                            if(alias in quote):
                                try:
                                    mentions.append(dict(zip(['qid_quote', 'qid_speaker','qid_mentioned'], [chunk['quoteID'][idd],chunk['qids'][idd],politic['qid']])))#  dump quoteID, and qid of speaker and cited
                                    total_mentions+=1
                                except KeyError as e:
                                    print(e,names_us['qid'])
                                break;
            t2=time.time()
            dt=t2-t1
            total_time+=dt
            chunk_number += 1
            print(chunk_number)
            print("from {} US political quotations there is {} mentions [time: {:.2f}]".format(chunk_number*CHUNKSIZE, total_mentions, total_time))
            #bzout_mention_usa.write(('\n'.join(map(json.dumps, mentions))+'\n').encode('utf-8'))
            #json.dump(bzout_mention_usa,orient='records',lines=True)
            pd.DataFrame(mentions).to_json(path_or_buf=bzout_mention_usa,orient='records',lines=True)
            mentions = []
# Out:
# 1
# from 200 US political quotations there is 11 mentions [time: 238.41]
# 4 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 6 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 6 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 41 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 49 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 60 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 65 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 65 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 73 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 81 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 81 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 85 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 85 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 85 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 85 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 88 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 92 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 96 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 109 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 109 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 109 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 109 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 109 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 156 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 167 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 180 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 193 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 195 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# 2
# from 400 US political quotations there is 11 mentions [time: 476.27]
# 2 0               Q207
# 5              Q4496
# 7             Q11124
# 9             Q11674
# 23            Q22201
#              ...
# 269177    Q107616155
# 269179    Q107618962
# 269202    Q107736981
# 269216    Q107976847
# 269218    Q108040695
# Name: qid, Length: 25760, dtype: object
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/r7/jht38nh56px_s6jkntzx89n00000gn/T/ipykernel_42171/3915950477.py in <module>
#      11             t1=time.time()
#      12             for idd,quote in enumerate(chunk.quotation) :
# ---> 13                 for index,politic in names_us.iterrows():
#      14                     if(politic['name'] in quote):
#      15                         try:
#
# ~/opt/anaconda3/envs/ada/lib/python3.8/site-packages/pandas/core/frame.py in iterrows(self)
#    1261         klass = self._constructor_sliced
#    1262         for k, v in zip(self.index, self.values):
# -> 1263             s = klass(v, index=columns, name=k)
#    1264             yield k, s
#    1265
#
# ~/opt/anaconda3/envs/ada/lib/python3.8/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     441                 manager = get_option("mode.data_manager")
#     442                 if manager == "block":
# --> 443                     data = SingleBlockManager.from_array(data, index)
#     444                 elif manager == "array":
#     445                     data = SingleArrayManager.from_array(data, index)
#
# ~/opt/anaconda3/envs/ada/lib/python3.8/site-packages/pandas/core/internals/managers.py in from_array(cls, array, index)
#    1572         Constructor for if we have an array that is not yet a Block.
#    1573         """
# -> 1574         block = new_block(array, placement=slice(0, len(index)), ndim=1)
#    1575         return cls(block, index)
#    1576
#
# ~/opt/anaconda3/envs/ada/lib/python3.8/site-packages/pandas/core/internals/blocks.py in new_block(values, placement, ndim, klass)
#    1935         klass = get_block_type(values, values.dtype)
#    1936
# -> 1937     values = maybe_coerce_values(values)
#    1938     return klass(values, ndim=ndim, placement=placement)
#    1939
#
# KeyboardInterrupt:

# %%
#LAST VERSION !!
#extraction of political name's mention from the quotes
try:
    os.remove(POLITICIANS_MENTIONS_USA)
except:
    pass
total_time,total_mentions,chunk_number,nb_quote=0,0,0,0
mentions=[]
with bz2.open(POLITICIANS_MENTIONS_USA, 'wb') as bzout_mention_usa:
    with pd.read_json(QUOTEBANK_POLITICIANS_USA, lines=True, chunksize=CHUNKSIZE, compression='bz2' ) as df_reader:
        for chunk in df_reader:
            t1=time.time()
            for quote in chunk.quotation :
                
                for index,politic in names_us.iterrows():
                    if(politic['name'] in quote):
                        try:
                            mentions.append(dict(zip(['qid_quote', 'qid_speaker','qid_mentioned'], [chunk['quoteID'][nb_quote],chunk['qids'][nb_quote],politic['qid']])))# dump quoteID, and qid of speaker and cited
                            total_mentions+=1
                        except KeyError as e:
                            print(e,politic['qid'])
                    else :
                        for alias in politic['aliases']:
                            if(alias in quote):
                                try:
                                    mentions.append(dict(zip(['qid_quote', 'qid_speaker','qid_mentioned'], [chunk['quoteID'][nb_quote],chunk['qids'][nb_quote],politic['qid']])))#  dump quoteID, and qid of speaker and cited
                                    total_mentions+=1
                                except KeyError as e:
                                    print(e,politic['qid'])
                                break;
                nb_quote+=1
            t2=time.time()
            dt=t2-t1
            total_time+=dt
            chunk_number += 1
            print(chunk_number)
            print("from {} US political quotations there is {} mentions [time: {:.2f} s]".format(chunk_number*CHUNKSIZE, total_mentions, total_time))
            #bzout_mention_usa.write(('\n'.join(map(json.dumps, mentions))+'\n').encode('utf-8'))
            #json.dump(bzout_mention_usa,orient='records',lines=True)
            pd.DataFrame(mentions).to_json(path_or_buf=bzout_mention_usa,orient='records',lines=True)
            mentions = []
# Out:
# 1
# from 200 US political quotations there is 11 mentions [time: 237.16]
# 2
# from 400 US political quotations there is 39 mentions [time: 472.25]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/r7/jht38nh56px_s6jkntzx89n00000gn/T/ipykernel_42171/3879944940.py in <module>
#      20                             print(e,politic['qid'])
#      21                     else :
# ---> 22                         for alias in politic['aliases']:
#      23                             if(alias in quote):
#      24                                 try:
#
# ~/opt/anaconda3/envs/ada/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~/opt/anaconda3/envs/ada/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1050         # Similar to Index.get_value, but we do not fall back to positional
#    1051         loc = self.index.get_loc(label)
# -> 1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#    1054     def __setitem__(self, key, value) -> None:
#
# ~/opt/anaconda3/envs/ada/lib/python3.8/site-packages/pandas/core/indexes/base.py in _get_values_for_loc(self, series, loc, key)
#    5183         """
#    5184         if is_integer(loc):
# -> 5185             return series._values[loc]
#    5186
#    5187         return series.iloc[loc]
#
# ~/opt/anaconda3/envs/ada/lib/python3.8/site-packages/pandas/core/series.py in _values(self)
#     704
#     705         """
# --> 706         return self._mgr.internal_values()
#     707
#     708     # error: Decorated property not supported
#
# ~/opt/anaconda3/envs/ada/lib/python3.8/site-packages/pandas/core/internals/managers.py in internal_values(self)
#    1672         return self._block.external_values()
#    1673
# -> 1674     def internal_values(self):
#    1675         """The array that Series._values returns"""
#    1676         return self._block.values
#
# KeyboardInterrupt:

# %%
#extraction of political name's mention from the quotes
try:
    os.remove(POLITICIANS_MENTIONS_USA)
except:
    pass
total_time,total_mentions,chunk_number=0,0,0
mentions=[]
with bz2.open(WIKI_DATA_FILTERED, 'wb') as d_file:
    for ii, entity_dict in enumerate(wjd):
        if entity_dict["type"] == "item":
            entity = WikidataItem(entity_dict)
            try:
                if ('P570' not in entity_dict['claims'].keys()):
                    if has_occupation_politician(entity):
                        try:
                            politicians.append(dict(zip(['qid', 'name','nationality'], [entity_dict['id'],entity_dict['labels']['en']['value'],entity_dict['claims']['P27'][-1]['mainsnak']['datavalue']['value']['id']])))# dump entity qid, name and nationality only
                        except KeyError as e:
                            print(e,entity_dict['id'])
            except Exception:
                print (Exception)
        if ii % 10000 == 0:
            t2 = time.time()
            dt = t2 - t1
            print(
                "Dumped {} politicians among {} entities [entities/s: {:.2f}]".format(
                    len(politicians), ii, ii / dt
                )
            )
            d_file.write(('\n'.join(map(json.dumps, politicians))+'\n').encode('utf-8'))
            politicians = []
#         if ii > 10000:
#             break

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/r7/jht38nh56px_s6jkntzx89n00000gn/T/ipykernel_40234/3906229033.py in <module>
#       4 with bz2.open(POLITICIANS_MENTIONS_USA, 'wb') as bzout_mention_usa:
#       5     with bz2.open(QUOTEBANK_POLITICIANS_USA,'wb' ) as df_reader:
# ----> 6         print(df_reader['quoteID'])
#
# TypeError: 'BZ2File' object is not subscriptable

# %%
with pd.read_json(POLITICIANS_MENTIONS_USA, lines=True, chunksize=10000, compression='bz2' ) as df_reader:
    nb=0
    for chunk in df_reader:
        print(chunk)
# Out:
#             qid_quote  qid_speaker qid_mentioned
# 0   2020-02-07-012379     [Q22686]        Q22686
# 1   2020-01-29-019304   [Q3957020]         Q6279
# 2   2020-01-29-019304   [Q3957020]       Q311269
# 3   2020-01-02-019876    [Q185480]        Q22686
# 4   2020-01-27-036296      [Q6279]         Q6279
# 5   2020-04-09-027891      [Q1124]         Q1124
# 6   2020-01-10-048465      [Q6279]         Q6279
# 7   2020-01-23-056683    [Q359442]         Q6279
# 8   2020-01-25-036997  [Q18209402]        Q22686
# 9   2020-02-03-087410    [Q359442]        Q22686
# 10  2020-01-16-004972     [Q59315]        Q22686
# 11  2020-02-07-012791  [Q18978140]      Q7793121
# 12  2020-02-20-010482     [Q22686]       Q461391
# 13  2020-02-20-010482     [Q22686]       Q170581
# 14  2020-01-29-035877      [Q4496]         Q4496
# 15  2020-03-12-028343   [Q1281204]         Q6279
# 16  2020-01-29-045741      [Q4496]       Q311269
# 17  2020-01-12-020460    [Q923242]       Q473239
# 18  2020-01-12-020460    [Q923242]       Q311269
# 19  2020-03-03-031314    [Q359442]        Q22686
# 20  2020-03-20-038435     [Q32620]        Q22686
# 21  2020-03-20-038435     [Q32620]         Q6279
# 22  2020-01-07-043391   [Q7173106]       Q359442
# 23  2020-01-07-043391   [Q7173106]        Q22222
# 24  2020-01-07-043391   [Q7173106]        Q22237
# 25  2020-01-07-043391   [Q7173106]       Q970720
# 26  2020-02-19-052699     [Q22686]        Q22316
# 27  2020-03-03-037855      [Q6279]        Q22686
# 28  2020-03-04-043949   [Q4897609]       Q359442
# 29  2020-04-14-043692   [Q5562913]       Q260042
# 30  2020-04-14-043692   [Q5562913]      Q5562913
# 31  2020-04-14-043692   [Q5562913]       Q505302
# 32  2020-04-14-043692   [Q5562913]      Q1973878
# 33  2020-04-14-043692   [Q5562913]      Q7794795
# 34  2020-02-26-078691     [Q22686]        Q22686
# 35  2020-03-03-070627   [Q7173106]        Q22686
# 36  2020-01-16-109375    [Q881146]       Q434706
# 37  2020-03-06-002525    [Q359442]         Q6279
# 38  2020-03-07-001547    [Q434804]         Q6279

# %%
stri1=['hello Donald Trump bg','efa']
#stri1.find('Dold')
name = names_us['name'].isin(stri1)
#if(names_us.name in stri1):
n=name[name==True]
print(n)

# %%
with pd.read_json(QUOTEBANK_POLITICIANS_USA, lines=True, chunksize=100000, compression='bz2' ) as df_reader:
    nb=0
    for chunk in df_reader:
        print(chunk[chunk['quoteID']=='2020-04-14-043692']['quotation'])
        quotate=(chunk[chunk['quoteID']=='2020-04-14-043692']['quotation'])
        break
        #for q_quote,qid,quote in chunk:
        #print(q_quote)
# Out:
# 309    Recognizing that their states have one integra...
# Name: quotation, dtype: object

# %%
len(quotate.values[0])
# Out:
# 1153

# %%
with pd.read_json(QUOTEBANK_POLITICIANS_USA, lines=True, chunksize=100000, compression='bz2' ) as df_reader:
    
    for chunk in df_reader:
        print(chunk) 
        #for q_quote,qid,quote in chunk:
        #print(q_quote)
# Out:
#                  quoteID                                          quotation  \
# 0      2020-01-16-000088  [ Department of Homeland Security ] was livid ...
# 1      2020-03-19-000276  [ These ] actions will allow households who ha...
# 2      2020-01-26-000499  a few of the candidates who will do better in ...
# 3      2020-01-20-000982                        a host of other protections
# 4      2020-01-03-001237  A lot of Americans [ were ] upset that this wa...
# ...                  ...                                                ...
# 99995  2020-03-22-043834  Where were the tests when we needed them? Wher...
# 99996  2020-01-25-058535  Whether it's OK for the president to sacrifice...
# 99997  2020-04-03-080197  While our hope is to return to classrooms befo...
# 99998  2020-02-28-089830  While they were working on impeachment, we wer...
# 99999  2020-02-01-061939  while this situation poses a very serious glob...
#
#                       speaker         qids                date  \
# 0                  Sue Myrick    [Q367796] 2020-01-16 12:00:13
# 1                  Ben Carson    [Q816459] 2020-03-19 19:14:00
# 2               Dave Loebsack    [Q771586] 2020-01-26 13:21:36
# 3                Debbie Lesko  [Q16731415] 2020-01-20 15:32:48
# 4               Julián Castro    [Q970720] 2020-01-03 00:00:00
# ...                       ...          ...                 ...
# 99995           J.B. Pritzker   [Q6103950] 2020-03-22 19:39:00
# 99996              Jason Crow  [Q58323071] 2020-01-25 00:42:05
# 99997           Tony Thurmond  [Q18631948] 2020-04-03 23:29:24
# 99998  President Donald Trump     [Q22686] 2020-02-28 04:14:35
# 99999           Ron Nirenberg  [Q30323642] 2020-02-01 06:00:00
#
#        numOccurrences                                             probas  \
# 0                   1  [[Sue Myrick, 0.8867], [None, 0.0992], [Ron Wy...
# 1                   1             [[Ben Carson, 0.9227], [None, 0.0773]]
# 2                  11  [[Dave Loebsack, 0.9011], [None, 0.0949], [Joe...
# 3                   1  [[Debbie Lesko, 0.4784], [None, 0.4105], [Ed M...
# 4                   1  [[Julián Castro, 0.4781], [None, 0.4384], [Dav...
# ...               ...                                                ...
# 99995               9  [[J.B. Pritzker, 0.8565], [None, 0.103], [Pres...
# 99996               1  [[Jason Crow, 0.8832], [None, 0.1081], [Donald...
# 99997               1  [[Tony Thurmond, 0.7087], [Gavin Newsom, 0.196...
# 99998               8  [[President Donald Trump, 0.8286], [Donald Tru...
# 99999               1          [[Ron Nirenberg, 0.5798], [None, 0.4202]]
#
#                                                     urls phase
# 0      [http://thehill.com/opinion/international/4782...     E
# 1      [https://mortgageorb.com/hud-fha-suspend-forec...     E
# 2      [http://rss.cnn.com/~r/rss/cnn_allpolitics/~3/...     E
# 3      [https://www.cleveland.com/open/2020/01/the-eq...     E
# 4      [http://keranews.org/post/juli-n-castro-ends-2...     E
# ...                                                  ...   ...
# 99995  [http://www.msn.com/en-us/news/politics/trump-...     E
# 99996  [https://www.freemalaysiatoday.com/category/wo...     E
# 99997  [https://www.danapointtimes.com/cusd-distance-...     E
# 99998  [http://cnn.com/2020/02/27/asia/novel-coronavi...     E
# 99999  [http://www.expressnews.com/news/local/article...     E
#
# [100000 rows x 9 columns]
#                   quoteID                                          quotation  \
# 100000  2020-03-18-093229  Who are you asking that question -- I see that...
# 100001  2020-01-09-113914         will impose additional punishing sanctions
# 100002  2020-04-07-070626  will not tolerate the price gouging and hoardi...
# 100003  2020-02-11-115981  With all challenges & differences, in defendin...
# 100004  2020-03-25-095098               won't transition to online learning,
# ...                   ...                                                ...
# 199995  2020-02-20-013727            dream scenario turned into a nightmare,
# 199996  2020-03-16-012788  During this COVID-19 public health emergency, ...
# 199997  2020-01-07-014417  empowers local leaders to employ federal funds...
# 199998  2020-02-21-012697  Enough is enough. No one should have to beg fo...
# 199999  2020-01-27-016575  families are already going hungry and people a...
#
#                        speaker                 qids                date  \
# 100000            Donald Trump  [Q22686, Q27947481] 2020-03-18 17:31:15
# 100001  President Donald Trump             [Q22686] 2020-01-09 21:11:10
# 100002         President Trump             [Q22686] 2020-04-07 00:00:00
# 100003            Donald Trump  [Q22686, Q27947481] 2020-02-11 22:11:00
# 100004           Denise Juneau           [Q5257693] 2020-03-25 06:00:44
# ...                        ...                  ...                 ...
# 199995             Paul Begala            [Q706803] 2020-02-20 00:00:00
# 199996         Ellen Rosenblum           [Q5364993] 2020-03-16 00:00:00
# 199997              Ben Carson            [Q816459] 2020-01-07 23:02:49
# 199998          Bernie Sanders            [Q359442] 2020-02-21 13:00:00
# 199999            Gavin Newsom            [Q461391] 2020-01-27 21:27:53
#
#         numOccurrences                                             probas  \
# 100000               1  [[Donald Trump, 0.9312], [None, 0.0662], [Joe ...
# 100001               1  [[President Donald Trump, 0.8538], [None, 0.12...
# 100002               1        [[President Trump, 0.9073], [None, 0.0927]]
# 100003               1  [[Donald Trump, 0.5361], [None, 0.4071], [Hass...
# 100004               1          [[Denise Juneau, 0.9134], [None, 0.0866]]
# ...                ...                                                ...
# 199995               1  [[Paul Begala, 0.3492], [Mike Bloomberg, 0.337...
# 199996               2        [[Ellen Rosenblum, 0.7516], [None, 0.2484]]
# 199997               1             [[Ben Carson, 0.9163], [None, 0.0837]]
# 199998               1         [[Bernie Sanders, 0.9584], [None, 0.0416]]
# 199999               1  [[Gavin Newsom, 0.9232], [None, 0.0686], [Davi...
#
#                                                      urls phase
# 100000  [https://www.politicususa.com/2020/03/18/trump...     E
# 100001  [http://worldmag.com/content/the_killing_of_th...     E
# 100002  [https://www.jdsupra.com/legalnews/rarely-invo...     E
# 100003  [http://express.co.uk/news/world/1241026/Iran-...     E
# 100004  [http://www.seattletimes.com/seattle-news/ther...     E
# ...                                                   ...   ...
# 199995  [https://www.foxnews.com/media/bloomberg-debat...     E
# 199996  [http://klcc.org/post/live-updates-oregon-has-...     E
# 199997  [https://www.al.com/news/2020/01/ben-carson-ev...     E
# 199998  [http://www.democracynow.org/2020/2/21/headlines]     E
# 199999  [http://www.sfchronicle.com/nation/article/Cou...     E
#
# [100000 rows x 9 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/r7/jht38nh56px_s6jkntzx89n00000gn/T/ipykernel_42171/2274562227.py in <module>
#       1 with pd.read_json(QUOTEBANK_POLITICIANS_USA, lines=True, chunksize=100000, compression='bz2' ) as df_reader:
#       2
# ----> 3     for chunk in df_reader:
#       4         print(chunk)
#       5         #for q_quote,qid,quote in chunk:
#
# ~/opt/anaconda3/envs/ada/lib/python3.8/site-packages/pandas/io/json/_json.py in __next__(self)
#     793                 raise StopIteration
#     794
# --> 795         lines = list(islice(self.data, self.chunksize))
#     796         if lines:
#     797             lines_json = self._combine_lines(lines)
#
# ~/opt/anaconda3/envs/ada/lib/python3.8/bz2.py in read1(self, size)
#     193             if size < 0:
#     194                 size = io.DEFAULT_BUFFER_SIZE
# --> 195             return self._buffer.read1(size)
#     196
#     197     def readinto(self, b):
#
# ~/opt/anaconda3/envs/ada/lib/python3.8/_compression.py in readinto(self, b)
#      66     def readinto(self, b):
#      67         with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68             data = self.read(len(byte_view))
#      69             byte_view[:len(data)] = data
#      70         return len(data)
#
# ~/opt/anaconda3/envs/ada/lib/python3.8/_compression.py in read(self, size)
#     101                 else:
#     102                     rawblock = b""
# --> 103                 data = self._decompressor.decompress(rawblock, size)
#     104             if data:
#     105                 break
#
# KeyboardInterrupt:

# %%
with pd.read_json(WIKI_DATA_FILTERED_LABELED, lines=True, chunksize=100000, compression='bz2' ) as df_reader:
    for chunk in df_reader:
        print(chunk)
# Out:
#               qid                  name gender nationality  \
# 0            Q207        George W. Bush   male         Q30
# 1            Q946           Donald Tusk   male         Q36
# 2           Q1058         Narendra Modi   male        Q668
# 3           Q1253           Ban Ki-moon   male        Q884
# 4           Q3996      V. P. Kalairajan   male        Q668
# ...           ...                   ...    ...         ...
# 99995  Q105840175  Frederick H. Magison   male         Q30
# 99996  Q105840242  James Goodridge Page   male         Q30
# 99997  Q105840296   William M. Robinson   male         Q30
# 99998  Q105840297         Silas B. Root   male         Q30
# 99999  Q105845441         Andres Taimla   male        Q191
#
#                                                  aliases  \
# 0      [George Walker Bush, Bush Jr., Dubya, GWB, Bus...
# 1                               [Donald Franciszek Tusk]
# 2      [Modi, Narendra Bhai, Narendra Damodardas Modi...
# 3                              [Ban Kimoon, Ban Ki Moon]
# 4                                                     []
# ...                                                  ...
# 99995                 [Frederick Magison, F. H. Magison]
# 99996            [James G. Page, James Page, J. G. Page]
# 99997                 [William Robinson, W. M. Robinson]
# 99998                           [Silas Root, S. B. Root]
# 99999                                                 []
#
#                                           parties  \
# 0                              [Republican Party]
# 1       [Civic Platform, European People's Party]
# 2                        [Bharatiya Janata Party]
# 3                        [independent politician]
# 4      [All India Anna Dravida Munnetra Kazhagam]
# ...                                           ...
# 99995                                          []
# 99996                                          []
# 99997                                          []
# 99998                                          []
# 99999                                          []
#
#                                           positions held religion  \
# 0      [Q5589725, [[+1995-01-17T00:00:00Z]], Q11696, ...  Q329646
# 1      [Q3259469, [[+2007-11-16T00:00:00Z]], Q735587,...    Q9592
# 2      [Q22337580, [[+2001-10-07T00:00:00Z]], Q425092...    Q9089
# 3      [Q81066, [[+2007-01-01T00:00:00Z]], [Foreign m...    Q9581
# 4                                      [Q24558764, [[]]]
# ...                                                  ...      ...
# 99995                 [[Q17342542, , ], [Q17342542, , ]]
# 99996                                  [[Q17342542, , ]]
# 99997  [[Q17342542, , ], [Q17342542, , ], [Q17342542,...
# 99998                 [[Q17342542, , ], [Q17342542, , ]]
# 99999                                  [[Q21100241, , ]]
#
#       us_congress_id                                 candidacy_election
# 0                     [2000 United States presidential election, 200...
# 1                                   [2005 Polish presidential election]
# 2                     [2014 Indian general election in Vadodara Lok ...
# 3                                                                    []
# 4                                                                    []
# ...              ...                                                ...
# 99995                                                                []
# 99996                                                                []
# 99997                                                                []
# 99998                                                                []
# 99999                                                                []
#
# [100000 rows x 10 columns]
#                qid                   name  gender nationality  \
# 100000  Q105846414  Valentina Võssotskaja  female        Q191
# 100001  Q105846465     William A. Bellamy    male         Q30
# 100002  Q105846468  Charles Cabot Johnson    male         Q30
# 100003  Q105846473     William H. Wheeler    male         Q30
# 100004  Q105847895    Daniel Edward Denny    male         Q30
# ...            ...                    ...     ...         ...
# 199995   Q98249959         Jérôme Bompard    male        Q142
# 199996   Q98249988          Vincent Chenu    male        Q142
# 199997   Q98249997     Jean-Claude Thomas    male        Q142
# 199998   Q98250005       Stéphane Guillou    male        Q142
# 199999   Q98250014      Bernard Dailcroix    male        Q142
#
#                                                   aliases parties  \
# 100000                                                 []      []
# 100001                   [William Bellamy, W. A. Bellamy]      []
# 100002  [Charles Johnson, Charles C. Johnson, C. C. Jo...      []
# 100003                   [William Wheeler, W. H. Wheeler]      []
# 100004       [Daniel Denny, Daniel E. Denny, D. E. Denny]      []
# ...                                                   ...     ...
# 199995                                                 []      []
# 199996                                                 []      []
# 199997                                                 []      []
# 199998                                                 []      []
# 199999                                                 []      []
#
#                                            positions held religion  \
# 100000                                  [[Q21100241, , ]]
# 100001  [[Q20058776, , ], [Q20058776, , ], [Q17342542,...
# 100002  [[Q20058776, , ], [Q17342542, , ], [Q20058776,...
# 100003  [[Q20058776, , ], [Q20058776, , ], [Q17342542,...
# 100004  [[Q20058776, , ], [Q20058776, , ], [Q20058776,...
# ...                                                   ...      ...
# 199995  [Q65491334, [[+2020-05-18T00:00:00Z]], Q652327...
# 199996  [Q65524818, [[+2020-05-18T00:00:00Z]], Q654600...
# 199997  [Q65493043, [[+2020-05-18T00:00:00Z]], Q652422...
# 199998  [Q65519578, [[+2020-05-18T00:00:00Z]], Q648260...
# 199999  [Q65518906, [[+2020-05-18T00:00:00Z]], Q625857...
#
#        us_congress_id candidacy_election
# 100000                                []
# 100001                                []
# 100002                                []
# 100003                                []
# 100004                                []
# ...               ...                ...
# 199995                                []
# 199996                                []
# 199997                                []
# 199998                                []
# 199999                                []
#
# [100000 rows x 10 columns]
#                qid                  name  gender nationality aliases  \
# 200000   Q98250016      Patrick Chambord    male        Q142      []
# 200001   Q98250025      Catherine Latche  female        Q142      []
# 200002   Q98250036      Jérôme Bouteloup    male        Q142      []
# 200003   Q98250052         Thomas Solans    male        Q142      []
# 200004   Q98250051  Jean-Pierre Bringard    male        Q142      []
# ...            ...                   ...     ...         ...     ...
# 269332  Q109129507         Dalibor Carda    male        Q213      []
# 269333  Q109182386   Ann-Britt Eira Sara  female         Q20      []
# 269334  Q109192686    Maja Kristine Jåma  female         Q20      []
# 269335  Q109198005     Ulf Tore Johansen    male         Q20      []
# 269336  Q109201564   Bharat Chandra Hota    male    Q1775277      []
#
#                              parties  \
# 200000                            []
# 200001                            []
# 200002                            []
# 200003                            []
# 200004                            []
# ...                              ...
# 269332                            []
# 269333      [Norwegian Labour Party]
# 269334  [Norwegian Sami Association]
# 269335            [Nordkalottfolket]
# 269336    [Indian National Congress]
#
#                                            positions held religion  \
# 200000  [Q65522647, [[+2020-05-18T00:00:00Z]], Q654593...
# 200001  [Q65498325, [[+2020-05-18T00:00:00Z]], Q653601...
# 200002  [Q65526637, [[+2020-05-18T00:00:00Z]], Q654605...
# 200003  [Q65481826, [[+2020-05-18T00:00:00Z]], Q651878...
# 200004  [Q65467343, [[+2020-05-18T00:00:00Z]], Q651792...
# ...                                                   ...      ...
# 269332  [Q99356295, [[+2018-00-00T00:00:00Z]], Q108899...
# 269333             [Q28940944, [[+2021-00-00T00:00:00Z]]]
# 269334             [Q28940944, [[+2021-00-00T00:00:00Z]]]
# 269335             [Q28940944, [[+2021-00-00T00:00:00Z]]]
# 269336             [Q61480559, [[+1967-00-00T00:00:00Z]]]
#
#        us_congress_id candidacy_election
# 200000                                []
# 200001                                []
# 200002                                []
# 200003                                []
# 200004                                []
# ...               ...                ...
# 269332                                []
# 269333                                []
# 269334                                []
# 269335                                []
# 269336                                []
#
# [69337 rows x 10 columns]
