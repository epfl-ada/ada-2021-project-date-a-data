# %%
import json
import bz2
import sys
import os
import pandas as pd
import time
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx
from collections import Counter, OrderedDict

# %%
USA_MENTIONS = 'quotebank_politicians_USA_mapped.json.bz2'

# %%
mentions_usa_df=pd.read_json(USA_MENTIONS,compression='bz2', lines=True)

# %%
WIKI_DATA_FILTERED = 'filtered_politician_labeled_v2.json.bz2'
qids_df=pd.read_json(WIKI_DATA_FILTERED, lines=True)

# %%
counts_USA_mentions=Counter(mentions_usa_df.qids.str[0])

# %%
sorted_count_mentions=sorted(counts_USA_mentions.items(), key=lambda x: x[1], reverse=True)

# %%
top_three= sorted_count_mentions[:3]

# %%
top_three
# Out:
# [('Q22686', 3101), ('Q359442', 2054), ('Q6279', 1877)]

# %%
top_three[0][0]
# Out:
# 'Q22686'

# %%
mentions_usa_df.head(4)
# Out:
#              quoteID                                          quotation  \
# 0  2020-02-07-012379  but [ President ] Trump (was) eager to make a ...
# 1  2020-01-29-019304  Even if it's all true, exactly in the worst-ca...
# 2  2020-01-02-019876  I enjoy your analysis and instruction on polli...
# 3  2020-01-27-036296  If your last name was not Biden, do you think ...
#
#                   speaker        qids                date  numOccurrences  \
# 0  President Donald Trump    [Q22686] 2020-02-07 23:05:05               1
# 1            Kevin Cramer  [Q3957020] 2020-01-29 01:01:16               1
# 2          Steve Bartlett   [Q185480] 2020-01-02 00:00:00               1
# 3               Joe Biden     [Q6279] 2020-01-27 14:33:49              14
#
#                                               probas  \
# 0  [[President Donald Trump, 0.5698], [None, 0.43...
# 1  [[Kevin Cramer, 0.8789], [None, 0.1072], [John...
# 2  [[Steve Bartlett, 0.9232], [None, 0.0754], [Pr...
# ...

# %%
mentionT=mentions_usa_df[mentions_usa_df.qids.str[0]==top_three[0][0]]

# %%
#TRUMP->Bernie
Trump_Bernie=mentionT[mentionT['mentions_qids'].isin([[top_three[1][0]]])]
Trump_Bernie
# Out:
#                  quoteID                                          quotation  \
# 40     2020-03-03-052722  The Democrat establishment is trying to take i...
# 136    2020-01-26-057664  You know he basically says we're getting screw...
# 383    2020-02-03-072114  The DNC on Bernie Sanders, `Looks like they're...
# 454    2020-02-23-005880       don't want Bernie Sanders to represent them.
# 2186   2020-02-23-012856  I read where Russia is helping Bernie Sanders....
# ...                  ...                                                ...
# 25355  2020-01-25-021192  If Bernie would have been VP it would have bee...
# 25871  2020-03-01-005681  Democrats are working hard to destroy the name...
# 27030  2020-02-03-072113  The DNC on Bernie Sanders, `Looks like they're...
# 27087  2020-03-09-012146  Elizabeth `Pocahontas Warren singlehandedly de...
# 27141  2020-01-27-078695  They are rigging the election again against Be...
#
# ...

# %%
Trump_Bernie2=mentionT[mentionT['mentions_qids'].isin([[top_three[2][0]]])]
Trump_Bernie2
# Out:
#                  quoteID                                          quotation  \
# 349    2020-03-29-015677  It's going to be Joe Biden, short of something...
# 362    2020-01-28-008912  Attorney General Bondi went through for you so...
# 481    2020-04-10-056628  We want to always make sure that we have a gre...
# 542    2020-03-09-038467  made it inescapably clear that he's terrified ...
# 566    2020-02-16-056982  You saw that [ Hunter Biden ] got into interna...
# ...                  ...                                                ...
# 26572  2020-01-15-115242  You ever notice with Biden he's always [ sayin...
# 26824  2020-03-02-002564  All of his SuperTuesday votes will go to Sleep...
# 26887  2020-01-09-041528  I'm going to leave it to the Senate, but I'd l...
# 26914  2020-01-28-061086          obsessed with Hunter Biden and Joe Biden.
# 27000  2020-03-02-002562  All of his SuperTuesday votes will go to Sleep...
#
# ...

# %%
menti2 = mentioned1[mentioned1['mentions_qids'].str.any('Q461391')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/r7/jht38nh56px_s6jkntzx89n00000gn/T/ipykernel_55300/1332571797.py in <module>
# ----> 1 menti2 = mentioned1[mentioned1['mentions_qids'].str.any('Q461391')]
#
# AttributeError: 'StringMethods' object has no attribute 'any'

# %%
mentioned2=mentions_usa_df[mentions_usa_df.qids.str[0]==top_three[0][0]]
# Out:
#                  quoteID                                          quotation  \
# 0      2020-02-07-012379  but [ President ] Trump (was) eager to make a ...
# 11     2020-02-20-010482  California used to be a beautiful State. It's ...
# 19     2020-02-19-052699   Kerry & Murphy illegally violated the Logan Act,
# 23     2020-02-26-078691  Trump has become furious about the stock marke...
# 28     2020-02-06-008475  As much as I disagree with Mitt Romney, I resp...
# ...                  ...                                                ...
# 27140  2020-01-27-069279  The Democrat controlled House never even asked...
# 27141  2020-01-27-078695  They are rigging the election again against Be...
# 27146  2020-02-22-038520  We are protecting people with preexisting cond...
# 27149  2020-01-31-121762                     would love to have Mike Pompeo
# 27152  2020-02-11-076670  That disdain was on display in his recent chis...
#
# ...

# %%
sorted_count_mentions[:3]
# Out:
# [('Q22686', 3101), ('Q359442', 2054), ('Q6279', 1877)]

# %%
# Build a dataframe with 4 connections
df = pd.DataFrame({ 'from':['A', 'B', 'C','A'], 'to':['D', 'A', 'E','C']})
 
# Build your graph
G=nx.from_pandas_edgelist(df, 'from', 'to')
 
# Plot it
nx.draw(G, with_labels=True)
plt.show()
