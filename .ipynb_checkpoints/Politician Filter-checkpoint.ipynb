# %% [markdown]
# # Required package
# [qwikidata](https://qwikidata.readthedocs.io/en/stable/)
# [json](https://docs.python.org/3/library/json.html)
# [bz2](https://docs.python.org/3/library/bz2.html)
# # Required data
# [wikidata dump](https://dumps.wikimedia.org/wikidatawiki/entities/)

# %%
import time
import json
import bz2
import sys
from qwikidata.entity import WikidataItem
from qwikidata.json_dump import WikidataJsonDump
from qwikidata.utils import dump_entities_to_json

# %%
WIKI_DATA_FULL = '../latest-all.json.bz2' #path to wiki data dump
WIKI_DATA_FILTERED = '../filtered_politician.json.bz2' #path to filtered wiki data dump
P_OCCUPATION = "P106" #politician ID in wikidata
Q_POLITICIAN = "Q82955" #politician ID in wikidata
P_COUNTRY = "P27" #country of recognized citizenship in wikidata

# %%
def has_occupation_politician(item: WikidataItem, truthy: bool = True) -> bool:
    """Return True if the Wikidata Item has occupation politician."""
    if truthy:
        claim_group = item.get_truthy_claim_group(P_OCCUPATION)
    else:
        claim_group = item.get_claim_group(P_OCCUPATION)

    occupation_qids = [
        claim.mainsnak.datavalue.value["id"]
        for claim in claim_group
        if claim.mainsnak.snaktype == "value"
    ]
    return Q_POLITICIAN in occupation_qids

# %%
# create an instance of WikidataJsonDump
wjd_dump_path = WIKI_DATA_FULL
wjd = WikidataJsonDump(wjd_dump_path)

# %%
# create an instance of WikidataJsonDump
wjd_dump_path = WIKI_DATA_FULL
wjd = WikidataJsonDump(wjd_dump_path)

# create an iterable of WikidataItem representing politicians
politicians = []
t1 = time.time()
with bz2.open(WIKI_DATA_FILTERED, 'wb') as d_file:
    for ii, entity_dict in enumerate(wjd):
        if entity_dict["type"] == "item":
            entity = WikidataItem(entity_dict)
            try:
                if ('P570' not in entity_dict['claims'].keys()):
                    if has_occupation_politician(entity):
                        try:
                            politicians.append(dict(zip(['qid', 'name','nationality'], [entity_dict['id'],entity_dict['labels']['en']['value'],entity_dict['claims']['P27'][-1]['mainsnak']['property']])))# dump entity qid, name and nationality only
                        except KeyError as e:
                            print(e,entity_dict['id'])
            except Exception:
                print Exception
        if ii % 10000 == 0:
            t2 = time.time()
            dt = t2 - t1
            print(
                "Dumped {} politicians among {} entities [entities/s: {:.2f}]".format(
                    len(politicians), ii, ii / dt
                )
            )
            d_file.write('\n'.join(map(json.dumps, politicians)).encode('utf-8'))
            politicians = []
#         if ii > 10000:
#             break
# Out:
# Dumped 0 politicians among 0 entities [entities/s: 0.00]
# Dumped 464 politicians among 10000 entities [entities/s: 1073.34]
# Dumped 653 politicians among 20000 entities [entities/s: 1059.41]
# Dumped 335 politicians among 30000 entities [entities/s: 1097.18]
# Dumped 649 politicians among 40000 entities [entities/s: 1167.62]
# 'en'
# Q394762
# Dumped 438 politicians among 50000 entities [entities/s: 1251.93]
# Dumped 499 politicians among 60000 entities [entities/s: 1300.72]
# 'en'
# Q595519
# Dumped 417 politicians among 70000 entities [entities/s: 1362.02]
# Dumped 271 politicians among 80000 entities [entities/s: 1418.51]
# Dumped 520 politicians among 90000 entities [entities/s: 1464.31]
# 'en'
# Q855006
# Dumped 213 politicians among 100000 entities [entities/s: 1504.03]
# Dumped 385 politicians among 110000 entities [entities/s: 1532.99]
# Dumped 274 politicians among 120000 entities [entities/s: 1558.75]
# Dumped 340 politicians among 130000 entities [entities/s: 1599.94]
# Dumped 211 politicians among 140000 entities [entities/s: 1640.32]
# Dumped 464 politicians among 150000 entities [entities/s: 1683.91]
# Dumped 532 politicians among 160000 entities [entities/s: 1719.17]
# Dumped 599 politicians among 170000 entities [entities/s: 1762.05]
# Dumped 459 politicians among 180000 entities [entities/s: 1808.76]
# Dumped 653 politicians among 190000 entities [entities/s: 1847.31]
# Dumped 734 politicians among 200000 entities [entities/s: 1879.16]
# Dumped 401 politicians among 210000 entities [entities/s: 1917.89]
# 'en'
# Q1819377
# 'en'
# Q1850404
# Dumped 184 politicians among 220000 entities [entities/s: 1963.24]
# Dumped 305 politicians among 230000 entities [entities/s: 1996.83]
# Dumped 235 politicians among 240000 entities [entities/s: 2031.11]
# 'en'
# Q2050623
# 'en'
# Q2077996
# Dumped 273 politicians among 250000 entities [entities/s: 2065.86]
# Dumped 306 politicians among 260000 entities [entities/s: 2105.20]
# Dumped 143 politicians among 270000 entities [entities/s: 2138.19]
# Dumped 189 politicians among 280000 entities [entities/s: 2171.12]
# Dumped 222 politicians among 290000 entities [entities/s: 2202.37]
# Dumped 231 politicians among 300000 entities [entities/s: 2230.98]
# Dumped 401 politicians among 310000 entities [entities/s: 2233.67]
# 'en'
# Q2681951
# Dumped 170 politicians among 320000 entities [entities/s: 2259.89]
# Dumped 290 politicians among 330000 entities [entities/s: 2295.77]
# Dumped 384 politicians among 340000 entities [entities/s: 2324.31]
# Dumped 267 politicians among 350000 entities [entities/s: 2351.57]
# Dumped 429 politicians among 360000 entities [entities/s: 2369.16]
# Dumped 728 politicians among 370000 entities [entities/s: 2380.46]
# Dumped 324 politicians among 380000 entities [entities/s: 2393.38]
# Dumped 487 politicians among 390000 entities [entities/s: 2404.78]
# Dumped 284 politicians among 400000 entities [entities/s: 2418.82]
# Dumped 292 politicians among 410000 entities [entities/s: 2423.36]
# Dumped 257 politicians among 420000 entities [entities/s: 2438.67]
# 'en'
# Q3698889
# 'en'
# Q3727273
# Dumped 243 politicians among 430000 entities [entities/s: 2447.05]
# Dumped 316 politicians among 440000 entities [entities/s: 2459.22]
# 'en'
# Q3918833
# Dumped 167 politicians among 450000 entities [entities/s: 2484.68]
# Dumped 103 politicians among 460000 entities [entities/s: 2510.81]
# 'en'
# Q4054401
# 'en'
# Q4054448
# 'en'
# Q4054449
# 'en'
# Q4055294
# 'en'
# Q4057516
# 'en'
# Q4057944
# 'en'
# Q4058714
# 'en'
# Q4061157
# 'en'
# Q4062146
# 'en'
# Q4068057
# 'en'
# Q4072490
# 'en'
# Q4072516
# 'en'
# Q4075646
# 'en'
# Q4077141
# 'en'
# Q4081516
# 'en'
# Q4084540
# 'en'
# Q4085186
# 'en'
# Q4086662
# 'en'
# Q4088206
# 'en'
# Q4100473
# 'en'
# Q4100584
# 'en'
# Q4122732
# 'en'
# Q4124236
# 'en'
# Q4131446
# Dumped 173 politicians among 470000 entities [entities/s: 2529.34]
# 'en'
# Q4139281
# 'en'
# Q4141755
# 'en'
# Q4146026
# 'en'
# Q4148286
# 'en'
# Q4149704
# 'en'
# Q4150385
# 'en'
# Q4152237
# 'en'
# Q4155504
# 'en'
# Q4155763
# 'en'
# Q4157028
# 'en'
# Q4157981
# 'en'
# Q4159644
# 'en'
# Q4159761
# 'en'
# Q4160287
# 'en'
# Q4161707
# 'en'
# Q4162742
# 'en'
# Q4164741
# 'en'
# Q4176804
# 'en'
# Q4178652
# 'en'
# Q4181885
# 'en'
# Q4184368
# 'en'
# Q4186854
# 'en'
# Q4191938
# 'en'
# Q4197402
# 'en'
# Q4199016
# 'en'
# Q4203539
# 'en'
# Q4206773
# 'en'
# Q4207548
# 'en'
# Q4209436
# 'en'
# Q4209738
# 'en'
# Q4210634
# 'en'
# Q4214067
# 'en'
# Q4215826
# 'en'
# Q4225538
# Dumped 166 politicians among 480000 entities [entities/s: 2546.90]
# 'en'
# Q4229324
# 'en'
# Q4229757
# 'en'
# Q4229995
# 'en'
# Q4230992
# 'en'
# Q4233385
# 'en'
# Q4234092
# 'en'
# Q4243208
# 'en'
# Q4250174
# 'en'
# Q4254343
# 'en'
# Q4255750
# 'en'
# Q4257568
# 'en'
# Q4258876
# 'en'
# Q4265369
# 'en'
# Q4272625
# 'en'
# Q4273951
# 'en'
# Q4275266
# 'en'
# Q4276241
# 'en'
# Q4278521
# 'en'
# Q4279490
# 'en'
# Q4281185
# 'en'
# Q4284816
# 'en'
# Q4286507
# 'en'
# Q4289778
# 'en'
# Q4292217
# 'en'
# Q4296015
# 'en'
# Q4302858
# 'en'
# Q4312191
# Dumped 147 politicians among 490000 entities [entities/s: 2563.47]
# 'en'
# Q4316155
# 'en'
# Q4318543
# 'en'
# Q4320159
# 'en'
# Q4328202
# 'en'
# Q4331081
# 'en'
# Q4331205
# 'en'
# Q4331601
# 'en'
# Q4336599
# 'en'
# Q4336627
# 'en'
# Q4338592
# 'en'
# Q4342400
# 'en'
# Q4344058
# 'en'
# Q4351639
# 'en'
# Q4361675
# 'en'
# Q4361822
# 'en'
# Q4368805
# 'en'
# Q4383109
# 'en'
# Q4384301
# 'en'
# Q4386925
# 'en'
# Q4388118
# 'en'
# Q4394098
# 'en'
# Q4395706
# 'en'
# Q4397139
# 'en'
# Q4397197
# 'en'
# Q4399169
# 'en'
# Q4409282
# 'en'
# Q4410912
# Dumped 146 politicians among 500000 entities [entities/s: 2581.52]
# 'en'
# Q4412779
# 'en'
# Q4417030
# 'en'
# Q4421666
# 'en'
# Q4424545
# 'en'
# Q4424732
# 'en'
# Q4424919
# 'en'
# Q4425762
# 'en'
# Q4441368
# 'en'
# Q4442782
# 'en'
# Q4445219
# 'en'
# Q4452022
# 'en'
# Q4452176
# 'en'
# Q4455649
# 'en'
# Q4458582
# 'en'
# Q4459631
# 'en'
# Q4460456
# 'en'
# Q4461689
# 'en'
# Q4465974
# 'en'
# Q4469498
# 'en'
# Q4475965
# 'en'
# Q4477297
# 'en'
# Q4484911
# 'en'
# Q4491607
# 'en'
# Q4492713
# 'en'
# Q4494825
# 'en'
# Q4495038
# 'en'
# Q4506001
# Dumped 109 politicians among 510000 entities [entities/s: 2595.62]
# 'en'
# Q4508274
# 'en'
# Q4513833
# 'en'
# Q4514342
# 'en'
# Q4520877
# 'en'
# Q4521127
# 'en'
# Q4521826
# 'en'
# Q4522407
# 'en'
# Q4523288
# 'en'
# Q4523459
# 'en'
# Q4523559
# 'en'
# Q4528747
# 'en'
# Q4534324
# 'en'
# Q4535214
# Dumped 97 politicians among 520000 entities [entities/s: 2618.17]
# Dumped 171 politicians among 530000 entities [entities/s: 2645.72]
# Dumped 530 politicians among 540000 entities [entities/s: 2663.21]
# Dumped 291 politicians among 550000 entities [entities/s: 2682.61]
# Dumped 325 politicians among 560000 entities [entities/s: 2702.26]
# Dumped 235 politicians among 570000 entities [entities/s: 2721.92]
# Dumped 363 politicians among 580000 entities [entities/s: 2740.06]
# Dumped 245 politicians among 590000 entities [entities/s: 2752.50]
# Dumped 347 politicians among 600000 entities [entities/s: 2763.71]
# 'en'
# Q5367821
# Dumped 461 politicians among 610000 entities [entities/s: 2779.53]
# Dumped 320 politicians among 620000 entities [entities/s: 2797.84]
# Dumped 545 politicians among 630000 entities [entities/s: 2811.73]
# 'en'
# Q5604082
# 'en'
# Q5674092
# 'en'
# Q5681438
# 'en'
# Q5682145
# 'en'
# Q5684225
# Dumped 372 politicians among 640000 entities [entities/s: 2829.87]
# 'en'
# Q5698149
# 'en'
# Q5703426
# 'en'
# Q5710728
# 'en'
# Q5718820
# 'en'
# Q5721657
# 'en'
# Q5732152
# 'en'
# Q5783823
# 'en'
# Q5787414
# 'en'
# Q5789004
# Dumped 336 politicians among 650000 entities [entities/s: 2853.41]
# 'en'
# Q5796782
# 'en'
# Q5817374
# 'en'
# Q5828183
# 'en'
# Q5875802
# 'en'
# Q5885064
# 'en'
# Q5889524
# Dumped 291 politicians among 660000 entities [entities/s: 2875.85]
# 'en'
# Q5898290
# 'en'
# Q5908915
# 'en'
# Q5909673
# 'en'
# Q5923800
# 'en'
# Q5938008
# 'en'
# Q5939425
# 'en'
# Q5939609
# 'en'
# Q5941539
# 'en'
# Q5945520
# 'en'
# Q5945888
# 'en'
# Q5946202
# 'en'
# Q5947344
# 'en'
# Q5948642
# 'en'
# Q5950005
# 'en'
# Q5950831
# 'en'
# Q5952163
# 'en'
# Q5952264
# 'en'
# Q5953292
# 'en'
# Q5954624
# 'en'
# Q5955576
# 'en'
# Q5956211
# 'en'
# Q5957906
# 'en'
# Q5958452
# 'en'
# Q5959744
# 'en'
# Q5961538
# 'en'
# Q5962028
# 'en'
# Q5962114
# 'en'
# Q5962311
# 'en'
# Q5963542
# 'en'
# Q5963658
# 'en'
# Q5964539
# Dumped 443 politicians among 670000 entities [entities/s: 2893.28]
# 'en'
# Q6017657
# 'en'
# Q6021827
# 'en'
# Q6049574
# 'en'
# Q6056293
# 'en'
# Q6061755
# Dumped 640 politicians among 680000 entities [entities/s: 2913.03]
# 'en'
# Q6100937
# Dumped 599 politicians among 690000 entities [entities/s: 2926.19]
# Dumped 821 politicians among 700000 entities [entities/s: 2927.67]
# Dumped 338 politicians among 710000 entities [entities/s: 2933.98]
# 'en'
# Q6377655
# 'en'
# Q6400304
# 'en'
# Q6400917
# 'en'
# Q6417357
# Dumped 209 politicians among 720000 entities [entities/s: 2944.33]
# 'en'
# Q6463962
# 'en'
# Q6466972
# Dumped 195 politicians among 730000 entities [entities/s: 2957.27]
# 'en'
# Q6539562
# 'en'
# Q6544504
# 'en'
# Q6549053
# 'en'
# Q6551789
# 'en'
# Q6561245
# 'en'
# Q6612985
# 'en'
# Q6620082
# Dumped 70 politicians among 740000 entities [entities/s: 2968.82]
# 'en'
# Q6673632
# 'en'
# Q6684933
# 'en'
# Q6715238
# Dumped 152 politicians among 750000 entities [entities/s: 2978.75]
# 'en'
# Q6751686
# 'en'
# Q6752360
# 'en'
# Q6761332
# 'en'
# Q6765279
# 'en'
# Q6766177
# 'en'
# Q6801061
# 'en'
# Q6804626
# Dumped 323 politicians among 760000 entities [entities/s: 2989.93]
# 'en'
# Q6811357
# 'en'
# Q6819754
# Dumped 238 politicians among 770000 entities [entities/s: 2998.61]
# 'en'
# Q6943194
# 'en'
# Q7002699
# Dumped 139 politicians among 780000 entities [entities/s: 3007.87]
# 'en'
# Q7043943
# Dumped 133 politicians among 790000 entities [entities/s: 3016.68]
# 'en'
# Q7186837
# Dumped 362 politicians among 800000 entities [entities/s: 3025.69]
# 'en'
# Q7247616
# 'en'
# Q7252533
# Dumped 127 politicians among 810000 entities [entities/s: 3038.83]
# Dumped 595 politicians among 820000 entities [entities/s: 3048.75]
# Dumped 281 politicians among 830000 entities [entities/s: 3062.32]
# Dumped 301 politicians among 840000 entities [entities/s: 3071.95]
# Dumped 205 politicians among 850000 entities [entities/s: 3081.90]
# Dumped 100 politicians among 860000 entities [entities/s: 3091.26]
# 'en'
# Q7813828
# Dumped 377 politicians among 870000 entities [entities/s: 3095.94]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_50800/1065184728.py in <module>
#       7 t1 = time.time()
#       8 with bz2.open(WIKI_DATA_FILTERED, 'wb') as d_file:
# ----> 9     for ii, entity_dict in enumerate(wjd):
#      10         if entity_dict["type"] == "item":
#      11             entity = WikidataItem(entity_dict)
#
# ~\anaconda3\lib\site-packages\qwikidata\json_dump.py in __iter__(self)
#      70     def __iter__(self) -> Iterator[Dict]:
#      71         """Iterate over lines in the file."""
# ---> 72         for line_str in self.iter_lines():
#      73             line_str = line_str.rstrip(",\n")
#      74             # first and last lines are opening and closing brackets
#
# ~\anaconda3\lib\site-packages\qwikidata\json_dump.py in iter_lines(self)
#      65         """Generate lines from JSON dump file."""
#      66         with self._open_dump_file() as fp:
# ---> 67             for linebytes in fp:
#      68                 yield linebytes.decode("utf-8")
#      69
#
# ~\anaconda3\lib\bz2.py in readline(self, size)
#     217         with self._lock:
#     218             self._check_can_read()
# --> 219             return self._buffer.readline(size)
#     220
#     221     def readlines(self, size=-1):
#
# ~\anaconda3\lib\_compression.py in readinto(self, b)
#      66     def readinto(self, b):
#      67         with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68             data = self.read(len(byte_view))
#      69             byte_view[:len(data)] = data
#      70         return len(data)
#
# ~\anaconda3\lib\_compression.py in read(self, size)
#     101                 else:
#     102                     rawblock = b""
# --> 103                 data = self._decompressor.decompress(rawblock, size)
#     104             if data:
#     105                 break
#
# KeyboardInterrupt:
